# %% [markdown]
# ### Initialization of packages

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Initialization of paths

# %%
file_path_trainlabels = os.getcwd() + '/data/train_labels.csv'
train_labels = pd.read_csv(file_path_trainlabels, index_col=False)
file_path_trainset = os.getcwd() +'/data/train_set/train_set/'

# %% [markdown]
# ### Train-Validation split

# %%
x_train, x_val, y_train, y_val = train_test_split(train_labels['img_name'], train_labels['label'], test_size=0.20)

# %%
x_train.reset_index(drop=True, inplace=True)
x_val.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)
y_val.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Exploration

# %%
image = plt.imread(file_path_trainset+'train_1.jpg')
image
# Out:
# array([[[ 15,  10,   6],
#         [ 15,  10,   6],
#         [ 15,  10,   6],
#         ...,
#         [207, 184, 152],
#         [202, 179, 148],
#         [194, 171, 140]],
#
#        [[ 16,  11,   7],
#         [ 16,  11,   7],
#         [ 16,  11,   7],
#         ...,
#         [206, 181, 150],
#         [199, 176, 144],
#         [191, 168, 136]],
#
#        [[ 18,  13,   9],
#         [ 18,  13,   9],
#         [ 18,  13,   9],
#         ...,
#         [202, 178, 142],
#         [196, 172, 136],
#         [187, 163, 129]],
#
#        ...,
#
#        [[  2,   2,   0],
#         [  1,   1,   0],
#         [  2,   2,   0],
#         ...,
#         [  5,   5,   5],
#         [  6,   6,   6],
#         [  6,   6,   6]],
#
#        [[  1,   1,   0],
#         [  1,   1,   0],
#         [  1,   1,   0],
#         ...,
#         [  6,   6,   6],
#         [  7,   7,   7],
#         [  7,   7,   7]],
#
#        [[  2,   2,   0],
#         [  1,   1,   0],
#         [  1,   1,   0],
# ...

# %%
plt.imshow(image)

# %%
train_labels.head()
# Out:
#       img_name  label
# 0  train_1.jpg     21
# 1  train_2.jpg     29
# 2  train_3.jpg     17
# 3  train_4.jpg     21
# 4  train_5.jpg     50

# %%
train_labels['label'].value_counts()
# Out:
# 71    525
# 37    494
# 57    491
# 61    490
# 9     489
#      ...
# 59    278
# 78    274
# 67    257
# 42    255
# 20     27
# Name: label, Length: 80, dtype: int64

# %% [markdown]
# ### Making Test CNN

# %%
test_model = models.Sequential()
test_model.add(layers.Conv2D(32, (3, 3), activation='sigmoid', input_shape=(200, 200, 1)))
